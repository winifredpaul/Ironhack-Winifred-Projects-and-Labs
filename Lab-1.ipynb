# %%
products =["t-shirt", "mug", "hat", "book", "keychain"]

# %%
inventory = {}  #Creating a dictionary

# %%
for product in products:                                             #looking up in the product list
    product_qty= int(input(f"The quantity of the {product}:") )      #creating user input
    inventory[product]= product_qty                                  #adding to dictionary
print(inventory)
# Out:
# The quantity of the t-shirt: 10
# The quantity of the mug: 12
# The quantity of the hat: 23
# The quantity of the book: 34
# The quantity of the keychain: 55
# {'t-shirt': 10, 'mug': 12, 'hat': 23, 'book': 34, 'keychain': 55}

# %%
customer_order =set()                                                  #Set creation

# %%
for i in range(3):                                                      #creating order list of 3 items by asking user input
    order_list = input(f"Enter the name of the products {products}")  
    if product in products:
        customer_order.add(order_list)
# Out:
# Enter the name of the products ['t-shirt', 'mug', 'hat', 'book', 'keychain'] mug
# Enter the name of the products ['t-shirt', 'mug', 'hat', 'book', 'keychain'] hat
# Enter the name of the products ['t-shirt', 'mug', 'hat', 'book', 'keychain'] book

# %%
print(customer_order)                                  #Printing customer order
# Out:
# {'hat', 'mug', 'book'}

# %%
total_product_ordered = len(customer_order)                                      #Calculating total order and percentage of product ordered against available order options
perc_product_order  = ( total_product_ordered/len(products) )*100
print(total_product_ordered)
print (perc_product_order,'%')
order_status =(total_product_ordered,perc_product_order)
# Out:
# 3
# 60.0 %

# %%
print("Order Statistics:")                                           # printing order details
print("Total Products Ordered:",(total_product_ordered))
print ("Percentage of Products Ordered:", (perc_product_order),"%")
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 60.0 %

# %%
for product in products:                                                        #finding inventory list
    if product in inventory:
        inventory[product]-=1

print(inventory)
# Out:
# {'t-shirt': 7, 'mug': 9, 'hat': 20, 'book': 31, 'keychain': 52}

# %%
for product, quantity in inventory.items():                                         #updated inventory list
    print(f"The quantity of {product} is {quantity}")
# Out:
# The quantity of t-shirt is 7
# The quantity of mug is 9
# The quantity of hat is 20
# The quantity of book is 31
# The quantity of keychain is 52
