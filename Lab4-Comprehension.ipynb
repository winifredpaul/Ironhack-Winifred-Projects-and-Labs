# %%
products =["t-shirt", "mug", "hat", "book", "keychain"]

# %%
def initialize_inventory(products):
    inventory = {product: int(input(f"Enter the quantity of {product} available: ")) for product in products}
    return inventory

# %%
inventory = initialize_inventory(products)
print(inventory)
# Out:
# Enter the quantity of t-shirt available:  23
# Enter the quantity of mug available:  32
# Enter the quantity of hat available:  22
# Enter the quantity of book available:  13
# Enter the quantity of keychain available:  34
# {'t-shirt': 23, 'mug': 32, 'hat': 22, 'book': 13, 'keychain': 34}

# %%
def get_customer_orders():
    n = int(input("Enter the number of customer orders: "))
    customer_orders = {input(f"Enter the name of product : ").strip().lower() 
        for i in range(n)}
    return customer_orders

# %%
customer_orders = get_customer_orders()
print(customer_orders)
# Out:
# Enter the number of customer orders:  4
# Enter the name of product :  book
# Enter the name of product :  mug
# Enter the name of product :  hat
# Enter the name of product :  keychain
# {'hat', 'mug', 'keychain', 'book'}

# %%
def total_order_price(customer_orders):
    print("Products in your order:", customer_orders)
    total = sum(float(input(f"Enter the price of {product}: "))
        for product in customer_orders)
    
    return total

# %%
total_order_price(customer_orders)
# Out:
# Products in your order: {'hat', 'mug', 'keychain', 'book'}
# Enter the price of hat:  9
# Enter the price of mug:  3
# Enter the price of keychain:  2
# Enter the price of book:  12
# 26.0

# %%
def update_inventory(customer_orders,inventory):
    for product in customer_orders:
        if inventory[product] >0:
            inventory[product] -= 1
        inventory={product:quantity 
              for product, quantity in inventory.items()  
              if quantity != 0}
    return inventory

# %%
inventory = update_inventory(customer_orders,inventory)
for product, quantity in inventory.items():
    print(f"{product}: {quantity}")
# Out:
# t-shirt: 23
# mug: 31
# hat: 21
# book: 12
# keychain: 33

# %%
def calculate_order_statistics (customer_orders,products):  
    total_product_ordered = len(customer_orders)                                      #Calculating total order and percentage of product ordered against available order options
    perc_product_order  = ( total_product_ordered/len(products) )*100
 
    return (total_product_ordered, perc_product_order)

# %%
calculate_order_statistics (customer_orders,products)
# Out:
# (4, 80.0)

# %%
def print_order_statistics(order_statistics):
    total_product_ordered, perc_product_order = order_statistics
    print("Total Products Ordered:", total_product_ordered)
    print("Percentage of Products Ordered:", perc_product_order, "%")

# %%
order_statistics = calculate_order_statistics(customer_orders, products)
print_order_statistics(order_statistics)
print(order_statistics)
# Out:
# Total Products Ordered: 4
# Percentage of Products Ordered: 80.0 %
# (4, 80.0)

# %%
print(initialize_inventory(products))
print(get_customer_orders())
print(print_order_statistics(order_statistics))
print(update_inventory(customer_orders,inventory))
print(total_order_price(customer_orders))
# Out:
# Enter the quantity of t-shirt available:  23
# Enter the quantity of mug available:  32
# Enter the quantity of hat available:  22
# Enter the quantity of book available:  13
# Enter the quantity of keychain available:  34
# {'t-shirt': 23, 'mug': 32, 'hat': 22, 'book': 13, 'keychain': 34}
# Enter the number of customer orders:  4
# Enter the name of product :  book
# Enter the name of product :  mug
# Enter the name of product :  hat
# Enter the name of product :  keychain
# {'hat', 'mug', 'keychain', 'book'}
# Total Products Ordered: 4
# Percentage of Products Ordered: 80.0 %
# None
# {'t-shirt': 23, 'mug': 30, 'hat': 20, 'book': 11, 'keychain': 32}
# Products in your order: {'hat', 'mug', 'keychain', 'book'}
# Enter the price of hat:  9
# Enter the price of mug:  3
# Enter the price of keychain:  2
# Enter the price of book:  12
# 26.0
